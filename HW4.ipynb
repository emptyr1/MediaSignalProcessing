# %% [markdown]
# #### Use cross-correlation (or auto-correlation) to find features or similarities/differences in images. Treat this as an exploratory exercise where you bring in different things to compare, and then analyze/discuss the results. You should also explore analyzing the cross-correlation output matrix to extract the highest/lowest values, in a way that makes sense with your particular material.

# %%
# %pylab inline
rcParams['figure.figsize'] = (10, 4) #wide graphs by default
from __future__ import print_function
from __future__ import division
quantiles = arange(30)

plot(quantiles, stats.poisson.pmf(quantiles, 4), 'o-')
plot(quantiles, stats.poisson.pmf(quantiles, 5), 'o-')
plot(quantiles, stats.poisson.pmf(quantiles, 20), 'o-')
legend(['$\lambda$ = 4','$\lambda$ = 5','$\lambda$ = 20'])
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
noise1 = random.random(44100) - 0.5
noise2 = random.random(44100) - 0.5
lags, c, lines, line = xcorr(noise1, noise2, maxlags=500, usevlines=False);
grid()

# %%
a = (rand(44100)*2) -1
print(a)
b = sin(linspace(0, 2*pi*200, 44100))*0.3
b.size
lags, c, lines, line = acorr(a + b, maxlags=500);
xlim(0,1000)
ylim(-0.5, 0.5)
# Out:
# [ 0.41887645 -0.41621714 -0.11058172 ..., -0.49690026  0.02115795
#   0.64464836]
# (-0.5, 0.5)

# %%
img = imread('data/dice.png')
imshow(img)
img.shape
# Out:
# (600, 800, 4)

# %%
o = imread('data/circle.png')

#o = o.astype(float).sum(axis=-1)/3
#o = where(o > 0.9, 1, -1)
imshow(o, cmap=cm.gray, interpolation='nearest')
o.shape
# Out:
# (256, 256, 4)

# %%
img = where(img > 0.8, -1, 1)
imshow(img, cmap='gray')
colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x11daa1f80>

# %%
from scipy.signal import correlate2d
cc = correlate2d(o, img)
imshow(cc)
colorbar()
gcf().set_figheight(8)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-129-2506d8e690d5> in <module>()
#       1 from scipy.signal import correlate2d
# ----> 2 cc = correlate2d(o, img)
#       3 imshow(cc)
#       4 colorbar()
#       5 gcf().set_figheight(8)
#
# /Users/mudy/anaconda/lib/python2.7/site-packages/scipy/signal/signaltools.pyc in correlate2d(in1, in2, mode, boundary, fillvalue)
#     607         warnings.simplefilter('ignore', np.ComplexWarning)
#     608         # FIXME: some cast generates a warning here
# --> 609         out = sigtools._convolve2d(in1, in2, 0, val, bval, fillvalue)
#     610
#     611     return out
#
# ValueError: object too deep for desired array

# %%
o.shape
# Out:
# (370,)

# %%
o = imread('data/circle.png')
imshow(o)

colorbar()
o = o.astype(float).sum(axis=-1)/3
o = where(o > 0.9, 1, -1)
imshow(o, cmap=cm.gray, interpolation='nearest')
