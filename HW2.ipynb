# %%
#Produce a soundfile from image data or vicecersa. 
#Try to condition and select the data to make the results as interesting as possible.

# %%
from scipy.io import wavfile
img = imread('data/flower.png')

# %%
img.dtype
img.shape
# Out:
# (339, 500, 3)

# %%
subplot(131)
imshow(img[:,:,0]) #showing the red layer
colorbar()
subplot(132)
imshow(img[:,:,1]) #showing the blue
colorbar()
gcf().set_figwidth(14)

# %%
red_only = img.copy()
red_only[:,:,0] = 0
red_only[:,:,2] = 0
imshow(red_only)

# %%
sig = img[122,:,1]
#plot(sig)
sig.dtype
sigout = list((sig.astype(float32) - 100) * 200)*10
plot(sigout)
