# %%
#Produce a soundfile from image data or vicecersa. 
#Try to condition and select the data to make the results as interesting as possible.

# %%
from scipy.io import wavfile
img = imread('data/flower.png')

# %%
img.dtype
img.shape
# Out:
# (339, 500, 3)

# %%
subplot(131)
imshow(img[:,:,0]) #showing the red layer
colorbar()
subplot(132)
imshow(img[:,:,1]) #showing the blue
colorbar()
gcf().set_figwidth(14)

# %%
red_only = img.copy()
red_only[:,:,0] = 0
red_only[:,:,2] = 0
imshow(red_only)

# %%
import random
sigRed = img[123,:,0]
sigGreen = img[100,:,1]
sigBlue = img[100:,:,2]
finalList = []

audioClip = []
sig.dtype
sigoutRed = list((sigRed.astype(float32) - 100) * 200)*20
sigoutGreen = array((sigGreen.astype(float32) - 100) * random.randint(160, 200))*20
sigoutBlue = array((sigBlue.astype(float32) - 100) * 200)*random.randint(12, 18)

plot(sigoutBlue)
#plot(sigoutRed)

#print numpy.squeeze(finalList)

audioClip.append(sigout)
audioClip2 = numpy.squeeze(audioClip)
'''
print audioClip
plot(sigout)

figure()

'''
# Out:
# '\nprint audioClip\nplot(sigout)\n\nfigure()\n\n'

# %%
wavfile.write('data/outImage.wav', 44100, array(sigoutRed, dtype=float32))

# %%
import random
sigRed = img[123,:,0]
sigGreen = img[200,:,1]
sigBlue = img[200,:,2]
finalList = []

audioClip = []
sig.dtype

sigoutRed = list((sigRed.astype(float32) - 100) * 400)*20
sigoutGreen = list((sigGreen.astype(float32) - 50) * random.randint(160, 200))*40
sigoutBlue = array((sigBlue.astype(float32) - 25) * 200)*random.randint(14, 20)

#plot(sigoutBlue)
plot(sigoutRed)
#print numpy.squeeze(finalList)

wavfile.write('data/outImage2.wav', 44100, array(sigoutRed+6*sigoutGreen + sigoutRed, dtype=float32))
