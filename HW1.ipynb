# %%
#Data source: http://support.spatialkey.com/spatialkey-sample-csv-data/
x = linspace(0, 2 * pi, 100)
y = sin(x)
grid()
xlabel('angle (rad)')
ylabel('sin()')
title('The Sine Function')
plot(x,y);

# %%
data = csv2rec('data/Sacramentorealestatetransactions.csv', delimiter=',')
#print data['zip']
#x = arange(len(data))
x = data['zip']
y = data['sq__ft']
plot(x, y, 'k-.')
xlabel('Zip Code')
ylabel('Size of proprty(sq ft)')
title('Which zip codes have bigger houses')
figure()
legend()
bar(x, y, color='red', width=0.3)  #not sure why the color is not working
bar(x + 0.1, data['beds'], color='blue', width=0.6)
# Out:
# /Users/mudy/anaconda/lib/python2.7/site-packages/matplotlib/axes.py:4747: UserWarning: No labeled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labeled objects found. "
# <Container object of 985 artists>
