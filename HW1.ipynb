# %%
#Data source: http://support.spatialkey.com/spatialkey-sample-csv-data/
x = linspace(0, 2 * pi, 100)
y = sin(x)
grid()
xlabel('angle (rad)')
ylabel('sin()')
title('The Sine Function')
plot(x,y);

# %%
data = csv2rec('data/Sacramentorealestatetransactions.csv', delimiter=',')
#print data['zip']
#x = arange(len(data))
x = data['zip']
y = data['sq__ft']
plot(x, y, 'k-.', ms=10, lw=3, alpha=0.7, mfc='white')
xlabel('Zip Code')
ylabel('Size of proprty(sq ft)')
title('Which zip codes have bigger houses')
figure()
legend()
xlabel('Zip Code')
ylabel('Size of proprty(sq ft)')
title('Which zip codes have bigger houses')
bar(x, y, width=0.3, color='red')  #not sure why the color is not working
bar(x + 0.1, data['beds'],  width=0.6, color='blue')
figure()
xlabel('Zip Code')
ylabel('Size of proprty(sq ft)')
title('Which zip codes have bigger houses')
scatter(x, y, color='red',s=10,edgecolor='none', marker=7)
savefig('output.pdf')
